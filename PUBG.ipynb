# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df =  pd.read_csv('C:/Users/RJ/OneDrive/Documents/PUBG.csv')

# %%
df.head()
# Out:
#       killed_by       killer_name  killer_placement  killer_position_x  \
# 0       Grenade   KrazyPortuguese               5.0          657725.10
# 1        SCAR-L  nide2Bxiaojiejie              31.0           93091.37
# 2          S686          Ascholes              43.0          366921.40
# 3  Down and Out        Weirdo7777               9.0          472014.20
# 4          M416         Solayuki1               9.0          473357.80
#
#    killer_position_y      map  \
# 0           146275.2  MIRAMAR
# 1           722236.4  MIRAMAR
# 2           421623.9  MIRAMAR
# 3           313274.8  MIRAMAR
# 4           318340.5  MIRAMAR
#
#                                             match_id  time      victim_name  \
# 0  2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   823  KrazyPortuguese
# 1  2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   194      X3evolution
# 2  2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   103          CtrlZee
# ...

# %%
df
# Out:
#                    killed_by       killer_name  killer_placement  \
# 0                    Grenade   KrazyPortuguese               5.0
# 1                     SCAR-L  nide2Bxiaojiejie              31.0
# 2                       S686          Ascholes              43.0
# 3               Down and Out        Weirdo7777               9.0
# 4                       M416         Solayuki1               9.0
# 5                      Punch     xuezhiqian717              26.0
# 6                        AKM         pdfjkkvjk              12.0
# 7                       S686         xiaogao13              27.0
# 8                       S686         Jingchita              40.0
# 9                        AKM      Alexande-999              25.0
# 10                     Punch      NameLessisME               8.0
# 11                       P92        Daerljgodi              20.0
# 12                      S686          JoyFeng-               3.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 12 columns):
# killed_by            1048575 non-null object
# killer_name          975428 non-null object
# killer_placement     975428 non-null float64
# killer_position_x    975428 non-null float64
# killer_position_y    975428 non-null float64
# map                  1037707 non-null object
# match_id             1048575 non-null object
# time                 1048575 non-null int64
# victim_name          1048575 non-null object
# victim_placement     1028589 non-null float64
# victim_position_x    1048575 non-null float64
# victim_position_y    1048575 non-null float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 96.0+ MB

# %%
df.describe()
# Out:
#        killer_placement  killer_position_x  killer_position_y          time  \
# count     975428.000000      975428.000000      975428.000000  1.048575e+06
# mean          15.036958      412124.300234      395057.287784  7.617338e+02
# std           15.085655      142472.917061      140105.668373  5.572714e+02
# min            1.000000           0.000000           0.000000  4.600000e+01
# 25%            4.000000      335195.475000      295090.750000  2.420000e+02
# 50%           10.000000      418000.100000      387039.250000  6.280000e+02
# 75%           21.000000      511312.750000      483357.000000  1.250000e+03
# max           99.000000      810447.900000      814953.900000  2.230000e+03
#
#        victim_placement  victim_position_x  victim_position_y
# count      1.028589e+06       1.048575e+06       1.048575e+06
# mean       2.553599e+01       3.952004e+05       3.793898e+05
# std        2.039981e+01       1.611111e+05       1.572273e+05
# ...

# %%
df.columns
# Out:
# Index(['killed_by', 'killer_name', 'killer_placement', 'killer_position_x',
#        'killer_position_y', 'map', 'match_id', 'time', 'victim_name',
#        'victim_placement', 'victim_position_x', 'victim_position_y'],
#       dtype='object')

# %%
df['killed_by'].describe()
# Out:
# count          1048575
# unique              56
# top       Down and Out
# freq            179682
# Name: killed_by, dtype: object

# %%
df.killed_by.unique()
# Out:
# array(['Grenade', 'SCAR-L', 'S686', 'Down and Out', 'M416', 'Punch', 'AKM',
#        'P92', 'Win94', 'M16A4', 'S12K', 'Hit by Car',
#        'death.WeapSawnoff_C', 'Kar98k', 'Tommy Gun', 'S1897', 'Bluezone',
#        'Micro UZI', 'P1911', 'SKS', 'Mini 14', 'Mk14', 'Falling', 'UMP9',
#        'P18C', 'Machete', 'Sickle', 'Groza', 'Crossbow', 'Drown', 'Vector',
#        'R1895', 'M249', 'Uaz', 'M24', 'VSS', 'Pan', 'AWM', 'RedZone',
#        'Motorbike', 'Buggy', 'death.ProjMolotov_DamageField_C', 'Dacia',
#        'DP-28', 'R45', 'Motorbike (SideCar)', 'death.Buff_FireDOT_C',
#        'Crowbar', 'AUG', 'Van', 'Pickup Truck', 'Aquarail', 'Boat',
#        'death.ProjMolotov_C', 'death.PG117_A_01_C', 'death.RedZoneBomb_C'], dtype=object)

# %% [markdown]
# <h1>Missing Data</h1>
# <br>
# Missing data is highlighted in yellow.  If a column does not have any missing data it will show as purple.

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
demo=df.groupby(['killed_by','time']).count()['map']
demo=demo.sort_values(ascending=False)
demo.head(10)
# Out:
# killed_by  time
# Bluezone   1491    505
#            1490    503
#            1489    500
# Punch      119     493
#            122     491
# Bluezone   1488    485
# Punch      121     481
#            118     475
#            117     474
#            120     473
# Name: map, dtype: int64

# %%
demo=df.groupby(['map','killed_by']).count()['time']
demo=demo.sort_values(ascending=False)
demo.head(10)
# Out:
# map      killed_by
# ERANGEL  Down and Out    143546
#          M416             93911
#          M16A4            78660
#          SCAR-L           76859
#          AKM              72408
#          UMP9             46295
#          Bluezone         41557
#          S1897            36588
# MIRAMAR  Down and Out     33798
# ERANGEL  Mini 14          27120
# Name: time, dtype: int64

# %%
demo=df.groupby(['map','killer_name']).count()['killed_by']
demo=demo.sort_values(ascending=False)
demo.head(10)
# Out:
# map      killer_name
# ERANGEL  #unknown          2308
# MIRAMAR  #unknown          2033
# ERANGEL  dajiji555           71
#          gogolnyg            62
#          997620078           59
# MIRAMAR  vip135888           51
# ERANGEL  q_QUN648314099      50
# MIRAMAR  651651646           48
# ERANGEL  mxs214              47
#          SAMSUNG-Note9       47
# Name: killed_by, dtype: int64

# %%
df = ['Grenade', 'SCAR-L', 'S686', 'Down and Out', 'M416', 'Punch', 'AKM',
       'P92', 'Win94', 'M16A4', 'S12K', 'Hit by Car',
       'death.WeapSawnoff_C', 'Kar98k', 'Tommy Gun', 'S1897', 'Bluezone',
       'Micro UZI', 'P1911', 'SKS', 'Mini 14', 'Mk14', 'Falling', 'UMP9',
       'P18C', 'Machete', 'Sickle', 'Groza', 'Crossbow', 'Drown', 'Vector',
       'R1895', 'M249', 'Uaz', 'M24', 'VSS', 'Pan', 'AWM', 'RedZone',
       'Motorbike', 'Buggy', 'death.ProjMolotov_DamageField_C', 'Dacia',
       'DP-28', 'R45', 'Motorbike (SideCar)', 'death.Buff_FireDOT_C',
       'Crowbar', 'AUG', 'Van', 'Pickup Truck', 'Aquarail', 'Boat',
       'death.ProjMolotov_C', 'death.PG117_A_01_C', 'death.RedZoneBomb_C']

from collections import Counter
print(Counter(df))
# Out:
# Counter({'Grenade': 1, 'SCAR-L': 1, 'S686': 1, 'Down and Out': 1, 'M416': 1, 'Punch': 1, 'AKM': 1, 'P92': 1, 'Win94': 1, 'M16A4': 1, 'S12K': 1, 'Hit by Car': 1, 'death.WeapSawnoff_C': 1, 'Kar98k': 1, 'Tommy Gun': 1, 'S1897': 1, 'Bluezone': 1, 'Micro UZI': 1, 'P1911': 1, 'SKS': 1, 'Mini 14': 1, 'Mk14': 1, 'Falling': 1, 'UMP9': 1, 'P18C': 1, 'Machete': 1, 'Sickle': 1, 'Groza': 1, 'Crossbow': 1, 'Drown': 1, 'Vector': 1, 'R1895': 1, 'M249': 1, 'Uaz': 1, 'M24': 1, 'VSS': 1, 'Pan': 1, 'AWM': 1, 'RedZone': 1, 'Motorbike': 1, 'Buggy': 1, 'death.ProjMolotov_DamageField_C': 1, 'Dacia': 1, 'DP-28': 1, 'R45': 1, 'Motorbike (SideCar)': 1, 'death.Buff_FireDOT_C': 1, 'Crowbar': 1, 'AUG': 1, 'Van': 1, 'Pickup Truck': 1, 'Aquarail': 1, 'Boat': 1, 'death.ProjMolotov_C': 1, 'death.PG117_A_01_C': 1, 'death.RedZoneBomb_C': 1})

# %% [markdown]
# <h1>Bar Chart</h1>
# <br><br>
# A breakdown of deaths base on the weapons that were used.  This can give an indiction of what were the most popular or available weapons.

# %%
df['killed_by'].value_counts()[:5].plot(kind='barh')

# %%
killed_by = df['map'].value_counts()
killed_by = killed_by[:5]
plt.show()

# %%
plt.hist(df.victim_placement.dropna(), bins=25)
# Out:
# (array([  85296.,  110437.,  105070.,  102400.,  107808.,  111816.,
#           96692.,   41632.,   38155.,   37743.,   36943.,   33959.,
#           17489.,   10095.,   10092.,   10066.,    9928.,    9761.,
#            9687.,    9495.,    9144.,    8776.,    8271.,    6158.,    1676.]),
#  array([   1.  ,    4.96,    8.92,   12.88,   16.84,   20.8 ,   24.76,
#           28.72,   32.68,   36.64,   40.6 ,   44.56,   48.52,   52.48,
#           56.44,   60.4 ,   64.36,   68.32,   72.28,   76.24,   80.2 ,
#           84.16,   88.12,   92.08,   96.04,  100.  ]),
#  <a list of 25 Patch objects>)

# %%
plt.hist(df.killer_placement.dropna(), bins=25)
# Out:
# (array([  2.80211000e+05,   1.49045000e+05,   1.11211000e+05,
#           9.17920000e+04,   8.29240000e+04,   7.07880000e+04,
#           5.03370000e+04,   2.79260000e+04,   2.36170000e+04,
#           1.95160000e+04,   1.60820000e+04,   1.20270000e+04,
#           5.78600000e+03,   6.04900000e+03,   5.48900000e+03,
#           4.86400000e+03,   4.25300000e+03,   3.75200000e+03,
#           3.09900000e+03,   2.48200000e+03,   1.88400000e+03,
#           1.15900000e+03,   7.45000000e+02,   3.39000000e+02,
#           5.10000000e+01]),
#  array([  1.  ,   4.92,   8.84,  12.76,  16.68,  20.6 ,  24.52,  28.44,
#          32.36,  36.28,  40.2 ,  44.12,  48.04,  51.96,  55.88,  59.8 ,
#          63.72,  67.64,  71.56,  75.48,  79.4 ,  83.32,  87.24,  91.16,
#          95.08,  99.  ]),
#  <a list of 25 Patch objects>)

# %% [markdown]
# <h1> Action</h1>
# <br>
# Time range for player's highest active.

# %%
sns.boxplot(x='time', data=df)

# %%
df['killer_placement'].value_count()[:20]plot(kind=)

# %% [markdown]
# <h1>Death vs Time</h1>
# <br>
# This shows the activity and the probabilty of death

# %%
sns.kdeplot(df.time.dropna(), shade=True)

# %%
sns.kdeplot(df.victim_placement.dropna(), shade=True)

# %%
sns.distplot(df.victim_placement.dropna())

# %%
sns.violinplot(df.killed_by)

# %%
df.sort_values(by=['time'], ascending=True)
# Out:
#             killed_by     killer_name  killer_placement  killer_position_x  \
# 950958        Falling             NaN               NaN                NaN
# 1016369       Falling             NaN               NaN                NaN
# 506467        Falling             NaN               NaN                NaN
# 53925         Falling             NaN               NaN                NaN
# 995295        Falling             NaN               NaN                NaN
# 114178         SCAR-L    Miele-Bajilu              76.0           92224.55
# 114162            Pan  Spacemasterwen              64.0           90883.23
# 788990        Falling             NaN               NaN                NaN
# 597848        Falling             NaN               NaN                NaN
# 935682          Punch             NaN               NaN                NaN
# 935690          Punch        YourSona              94.0          554984.40
# ...

# %% [markdown]
# <h1> Total Kills Per Weapon</h1>

# %%
df.groupby('killed_by').victim_placement.sum()

# %%
df.sort_values(by=['killed_by'], ascending=True)
# Out:
#                   killed_by      killer_name  killer_placement  \
# 703298                  AKM      lilijingnan              26.0
# 847476                  AKM         Amor-008               3.0
# 175615                  AKM           Mar-24               5.0
# 764172                  AKM          8X-u666               5.0
# 962422                  AKM        Edwina-Lu              14.0
# 74769                   AKM      ReliableRPG              17.0
# 579126                  AKM    MybelovedAnna               1.0
# 847488                  AKM    DeepFriedRock              10.0
# 74766                   AKM      ReliableRPG              17.0
# 410229                  AKM        Chuan1123              10.0
# 74764                   AKM  peanut-aii-over              24.0
# 410228                  AKM           shjakl               9.0
# 74762                   AKM       DongCheng9               2.0
# 410226                  AKM           LuluII              27.0
# ...

# %% [markdown]
# <h1>Player KIA</h1>
# <br><br>
# Mean deaths per weapon an opponent was killed.

# %%
df.groupby('killed_by').victim_placement.mean()
# Out:
# killed_by
# AKM                                27.048256
# AUG                                 9.667028
# AWM                                10.004612
# Aquarail                           14.125000
# Bluezone                           20.756966
# Boat                               13.166667
# Buggy                              19.392583
# Crossbow                           37.355828
# Crowbar                            42.592040
# DP-28                              29.948201
# Dacia                              15.329953
# Down and Out                       17.365769
# Drown                              36.420504
# Falling                            28.627782
# Grenade                            20.265385
# Groza                              11.868080
# Hit by Car                         30.605923
# Kar98k                             17.776877
# M16A4                              26.607161
# M24                                10.749441
# M249                               11.913586
# ...

# %% [markdown]
# <h1> Offense KIA</h1>
# <br>
# Number of times an opponent was killed.

# %%
df.groupby('killed_by').killer_placement.mean()
# Out:
# killed_by
# AKM                                15.379438
# AUG                                 4.882664
# AWM                                 4.425550
# Aquarail                           11.444444
# Bluezone                            5.691090
# Boat                                7.977941
# Buggy                              16.110733
# Crossbow                           22.462850
# Crowbar                            27.845588
# DP-28                              18.410011
# Dacia                               9.031373
# Down and Out                       10.210988
# Drown                               9.962617
# Falling                            15.625774
# Grenade                            15.465659
# Groza                               5.657951
# Hit by Car                         18.311894
# Kar98k                              8.837404
# M16A4                              15.074578
# M24                                 4.734784
# M249                                5.779130
# ...

# %% [markdown]
# <h1> KIA Time</h1>
# <br>
# A time breakdown on an opponent in seconds if someone has the following weapons:

# %%
df.groupby('killed_by').time.mean()
# Out:
# killed_by
# AKM                                 690.746454
# AUG                                1460.398520
# AWM                                1470.776027
# Aquarail                            810.111111
# Bluezone                           1280.918516
# Boat                               1099.065217
# Buggy                               855.612658
# Crossbow                            358.074300
# Crowbar                             190.156863
# DP-28                               474.557685
# Dacia                              1005.392763
# Down and Out                        918.527359
# Drown                               419.180184
# Falling                             748.704864
# Grenade                             920.295763
# Groza                              1395.501384
# Hit by Car                          713.465079
# Kar98k                             1134.215825
# M16A4                               717.679917
# M24                                1447.249763
# ...

# %%
df['killed_by'].mean()[:10]

# %%
df.groupby('killer_placement').time.mean()
# Out:
# killer_placement
# 1.0     1233.994910
# 2.0     1184.483263
# 3.0     1110.811560
# 4.0     1039.348537
# 5.0      976.404477
# 6.0      929.803250
# 7.0      882.809563
# 8.0      839.754530
# 9.0      792.269874
# 10.0     745.917572
# 11.0     710.000483
# 12.0     668.485587
# 13.0     634.622695
# 14.0     592.410416
# 15.0     555.315919
# 16.0     518.854733
# 17.0     492.952348
# 18.0     460.459162
# 19.0     438.015564
# 20.0     411.231593
# 21.0     391.978094
# 22.0     369.330333
# 23.0     357.912548
# 24.0     344.247783
# 25.0     344.020381
# 26.0     370.832568
# 27.0     381.453342
# 28.0     387.941226
# 29.0     374.514238
# 30.0     361.173406
#            ...
# 70.0     142.781145
# 71.0     140.464120
# 72.0     138.299194
# 73.0     135.313492
# 74.0     128.992157
# 75.0     129.165021
# 76.0     126.355619
# 77.0     126.288288
# 78.0     119.376491
# 79.0     120.062738
# 80.0     117.914563
# 81.0     114.334711
# 82.0     113.245763
# ...

# %%
df.stack().value_counts()[:10]

# %%
sns.pairplot(df,hue='killed_by')
# Out:
# C:\Users\RJ\Anaconda3.1\lib\site-packages\numpy\lib\function_base.py:748: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# C:\Users\RJ\Anaconda3.1\lib\site-packages\numpy\lib\function_base.py:749: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)

# %%
df['killed_by'].value_counts()[:5]
# Out:
# Down and Out    179682
# M416            120754
# SCAR-L           97853
# M16A4            95994
# AKM              89601
# Name: killed_by, dtype: int64

# %%
df['map'].value_counts()[:5].plot(kind= 'barh')

# %%
df['killed_by'].value_counts()[:5].plot(kind= 'violin')
